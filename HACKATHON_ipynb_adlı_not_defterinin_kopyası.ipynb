# %%
#kütüphanlerin yüklenmesi
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Activation, BatchNormalization, Flatten
import cv2 #opencv
import os #dosya yolları için yardımcı olacak
import time
import uuid
import glob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#klasör yolu
print(os.listdir("/content/drive/MyDrive/Hackathon"))

#sabitlerin belirlenmesi
image_width= 128
image_height= 128
image_size=(image_width,image_height)
image_channels= 3 #görüntüler RGB olduğu için

#eğitim verisinin hazırlanması
filenames=os.listdir("/content/drive/MyDrive/Hackathon/train")
categories=[]
# Out:
# ['train', 'test']

# %%
#cardboard glass
for filename in filenames:
    category=filename[0:2]
    if category == "ca":
       categories.append((1)) 
    elif category == "gl":
       categories.append((2)) 
    elif category == "me":
       categories.append((3))  
    elif category == "pa":
       categories.append((4)) 
    elif category == "pl":
       categories.append((5))

# %%
df=pd.DataFrame({"filename":filenames,"category":categories})
df
# Out:
#               filename  category
# 0         glass173.jpg         2
# 1     cardboard201.jpg         1
# 2     cardboard164.jpg         1
# 3         glass288.jpg         2
# 4         glass270.jpg         2
# ...                ...       ...
# 1495  cardboard149.jpg         1
# 1496      glass243.jpg         2
# 1497      glass290.jpg         2
# 1498      glass231.jpg         2
# 1499  cardboard159.jpg         1
#
# [1500 rows x 2 columns]

# %%
#verilerin bar gösterimi 

df["category"].value_counts().plot.bar()

# %%
#rastgele görüntü seçilmesi
sample=random.choice(filenames)
image=load_img("/content/drive/MyDrive/Hackathon/train/"+sample)
plt.imshow(image)

# %%
# Modelin oluşturulması
model = Sequential()
model.add(Conv2D(32,(3,3) , activation="relu", input_shape=(image_width,image_height,image_channels)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(64,(3,3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(128,(3,3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512 , activation= "relu"))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(5, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 12,944,325
# Trainable params: 12,942,853
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
#modelin derlenmesi

model.compile(loss="categorical_crossentropy",optimizer="rmsprop",metrics=["accuracy"])

# %%
#verilerin hazırlanması
df["category"]=df["category"].replace({ 1 : "cardboard", 2 : "glass", 3 : "metal", 4 : "paper", 5 : "plastic"})
train_df, validate_df = train_test_split(df,test_size=0.2)
train_df=train_df.reset_index(drop=True)
validate_df=validate_df.reset_index(drop=True)

# %%
#kategorilere bakılması
train_df["category"].value_counts().plot.bar()

# %%
#eğitim ve doğrulanma verisinin hazırlanması
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %%
#eğitim verilerinin çoğaltılması
train_datagen = ImageDataGenerator(
    rotation_range =15,
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    
)

# %%
train_generator=train_datagen.flow_from_dataframe(
    train_df,
    "/content/drive/MyDrive/Hackathon/train/",
    x_col = "filename",
    y_col="category",
    target_size=image_size,
    class_mode="categorical",
    batch_size=batch_size
    
)
# Out:
# Found 1200 validated image filenames belonging to 5 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
validation_generator=validation_datagen.flow_from_dataframe(
    validate_df,
    "/content/drive/MyDrive/Hackathon/train/",
    x_col = "filename",
    y_col="category",
    target_size=image_size,
    class_mode="categorical",
    batch_size=batch_size
    
)
# Out:
# Found 300 validated image filenames belonging to 5 classes.

# %%
#modelin eğitilmesi
epochs=50
history=model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate,
    
)
# Out:
# Epoch 1/50
# 80/80 [==============================] - ETA: 0s - loss: 2.0371 - accuracy: 0.4250WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 300 batches). You may need to use the repeat() function when building your dataset.
# 80/80 [==============================] - 91s 904ms/step - loss: 2.0371 - accuracy: 0.4250 - val_loss: 3.7463 - val_accuracy: 0.1700
# Epoch 2/50
# 80/80 [==============================] - 66s 822ms/step - loss: 1.5090 - accuracy: 0.4725
# Epoch 3/50
# 80/80 [==============================] - 65s 810ms/step - loss: 1.3467 - accuracy: 0.5217
# Epoch 4/50
# 80/80 [==============================] - 65s 809ms/step - loss: 1.1769 - accuracy: 0.5783
# Epoch 5/50
# 80/80 [==============================] - 65s 810ms/step - loss: 1.0464 - accuracy: 0.6200
# Epoch 6/50
# 80/80 [==============================] - 65s 808ms/step - loss: 0.9851 - accuracy: 0.6317
# Epoch 7/50
# 80/80 [==============================] - 65s 816ms/step - loss: 0.9392 - accuracy: 0.6633
# Epoch 8/50
# 80/80 [==============================] - 66s 817ms/step - loss: 0.8939 - accuracy: 0.6608
# Epoch 9/50
# 80/80 [==============================] - 66s 823ms/step - loss: 0.8665 - accuracy: 0.6867
# Epoch 10/50
# 80/80 [==============================] - 66s 823ms/step - loss: 0.8075 - accuracy: 0.6983
# Epoch 11/50
# 80/80 [==============================] - 66s 822ms/step - loss: 0.7657 - accuracy: 0.7183
# Epoch 12/50
# 80/80 [==============================] - 65s 817ms/step - loss: 0.7284 - accuracy: 0.7275
# Epoch 13/50
# 80/80 [==============================] - 66s 819ms/step - loss: 0.7395 - accuracy: 0.7408
# Epoch 14/50
# 80/80 [==============================] - 65s 816ms/step - loss: 0.6979 - accuracy: 0.7542
# Epoch 15/50
# 80/80 [==============================] - 64s 804ms/step - loss: 0.6635 - accuracy: 0.7617
# Epoch 16/50
# 80/80 [==============================] - 64s 802ms/step - loss: 0.6573 - accuracy: 0.7533
# Epoch 17/50
# 80/80 [==============================] - 65s 809ms/step - loss: 0.6414 - accuracy: 0.7642
# Epoch 18/50
# 80/80 [==============================] - 66s 820ms/step - loss: 0.5927 - accuracy: 0.7758
# Epoch 19/50
# 80/80 [==============================] - 66s 824ms/step - loss: 0.6067 - accuracy: 0.7817
# Epoch 20/50
# 80/80 [==============================] - 65s 817ms/step - loss: 0.6076 - accuracy: 0.7858
# Epoch 21/50
# 80/80 [==============================] - 65s 812ms/step - loss: 0.5386 - accuracy: 0.8083
# Epoch 22/50
# 80/80 [==============================] - 65s 811ms/step - loss: 0.5267 - accuracy: 0.8225
# Epoch 23/50
# 80/80 [==============================] - 66s 824ms/step - loss: 0.5129 - accuracy: 0.8200
# Epoch 24/50
# 80/80 [==============================] - 66s 821ms/step - loss: 0.5386 - accuracy: 0.8100
# Epoch 25/50
# 80/80 [==============================] - 66s 825ms/step - loss: 0.5593 - accuracy: 0.8050
# Epoch 26/50
# 80/80 [==============================] - 65s 817ms/step - loss: 0.4644 - accuracy: 0.8342
# Epoch 27/50
# 80/80 [==============================] - 66s 818ms/step - loss: 0.5040 - accuracy: 0.8233
# Epoch 28/50
# 80/80 [==============================] - 66s 824ms/step - loss: 0.5063 - accuracy: 0.8225
# Epoch 29/50
# 80/80 [==============================] - 65s 817ms/step - loss: 0.4517 - accuracy: 0.8358
# Epoch 30/50
# 80/80 [==============================] - 66s 825ms/step - loss: 0.4786 - accuracy: 0.8208
# Epoch 31/50
# 80/80 [==============================] - 66s 827ms/step - loss: 0.4930 - accuracy: 0.8325
# Epoch 32/50
# 80/80 [==============================] - 66s 821ms/step - loss: 0.4529 - accuracy: 0.8400
# Epoch 33/50
# 80/80 [==============================] - 66s 821ms/step - loss: 0.4915 - accuracy: 0.8242
# Epoch 34/50
# 80/80 [==============================] - 66s 819ms/step - loss: 0.4218 - accuracy: 0.8558
# Epoch 35/50
# 80/80 [==============================] - 66s 817ms/step - loss: 0.4107 - accuracy: 0.8450
# Epoch 36/50
# 80/80 [==============================] - 66s 817ms/step - loss: 0.4070 - accuracy: 0.8592
# Epoch 37/50
# 80/80 [==============================] - 65s 812ms/step - loss: 0.3741 - accuracy: 0.8683
# Epoch 38/50
# 80/80 [==============================] - 64s 803ms/step - loss: 0.4104 - accuracy: 0.8575
# Epoch 39/50
# 80/80 [==============================] - 64s 799ms/step - loss: 0.3920 - accuracy: 0.8567
# Epoch 40/50
# 80/80 [==============================] - 64s 802ms/step - loss: 0.4038 - accuracy: 0.8625
# Epoch 41/50
# 80/80 [==============================] - 64s 801ms/step - loss: 0.3655 - accuracy: 0.8633
# Epoch 42/50
# 80/80 [==============================] - 64s 804ms/step - loss: 0.3631 - accuracy: 0.8717
# Epoch 43/50
# 80/80 [==============================] - 65s 812ms/step - loss: 0.3644 - accuracy: 0.8600
# Epoch 44/50
# 80/80 [==============================] - 64s 804ms/step - loss: 0.3215 - accuracy: 0.8950
# Epoch 45/50
# 80/80 [==============================] - 65s 805ms/step - loss: 0.3482 - accuracy: 0.8667
# Epoch 46/50
# 80/80 [==============================] - 66s 820ms/step - loss: 0.3354 - accuracy: 0.8767
# Epoch 47/50
# 80/80 [==============================] - 65s 809ms/step - loss: 0.3460 - accuracy: 0.8867
# Epoch 48/50
# 80/80 [==============================] - 65s 816ms/step - loss: 0.3539 - accuracy: 0.8725
# Epoch 49/50
# 80/80 [==============================] - 66s 819ms/step - loss: 0.3412 - accuracy: 0.8825
# Epoch 50/50
# 80/80 [==============================] - 66s 819ms/step - loss: 0.3322 - accuracy: 0.8817

# %%
#eğitim ve doğrulama verilerinin gösterimi
fig,(ax1,ax2)=plt.subplots(2,1,figsize=(12,12))
ax1.plot(history.history["loss"],color="b",label="Eğitim Kaybı")
ax1.plot(history.history["val_loss"],color="r",label="Doğrulama Kaybı")
ax1.set_xticks(np.arange(1,epochs,1))
ax1.set_yticks(np.arange(0,1,0.1))

ax2.plot(history.history["accuracy"],color="b",label="Eğitim Başarımı")
ax2.plot(history.history["val_accuracy"],color="r",label="Doğrulama Başarımı")
ax2.set_xticks(np.arange(1,epochs,1))

legend=plt.legend(loc="best",shadow=True)
plt.tight_layout()
plt.show()

# %%
#test verisinin hazırlanması
test_filenames=os.listdir("/content/drive/MyDrive/Hackathon/test/")
test_df=pd.DataFrame({
    "filename":test_filenames
})
nb_samples=test_df.shape[0]

# %%
#test verilerinin çoğaltılması

test_gen=ImageDataGenerator(rescale=1./255)
test_generator=test_gen.flow_from_dataframe(
    test_df,
    "/content/drive/MyDrive/Hackathon/test/",
    x_col = "filename",
    y_col=None,
    class_mode=None,
    target_size=image_size,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 500 validated image filenames.

# %%
#tahmin işleminin yapılması
predict=model.predict_generator(test_generator,steps=np.ceil(nb_samples/batch_size))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.

# %%
#tahmin işleminin hangi kategoriye ait olduğunu belirleme
test_df["category"]=np.argmax(predict,axis=-1)
label_map=dict((v,k) for k,v in train_generator.class_indices.items())
test_df["category"]=test_df["category"].replace(label_map)

# %%
#tahminlerin değerlendirilmesi
sample_test=test_df.head(18)
sample_test.head()
plt.figure(figsize=(12,24))
for index, row in sample_test.iterrows():
    filename=row["filename"]
    category=row["category"]
    img=load_img("/content/drive/MyDrive/Hackathon/test/"+filename,target_size=image_size)
    plt.subplot(6,3,index+1)
    plt.imshow(img)
    plt.xlabel(filename + "(" +  "{}".format(category)  +  ")")
plt.tight_layout()
plt.show()
